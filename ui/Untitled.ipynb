# %%
# !pip install rasterio
# Out:
# ...
#   Using cached rasterio-1.2.3.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\R00TKIT\anaconda3\python.exe' 'C:\Users\R00TKIT\anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' get_requires_for_build_wheel 'C:\Users\R00TKIT\AppData\Local\Temp\tmppfspoen2'
#        cwd: C:\Users\R00TKIT\AppData\Local\Temp\pip-install-omnkvwen\rasterio
#   Complete output (2 lines):
#   INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#   ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
# ...

# %%
# !pip install GDAL
# Out:
# ...
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\R00TKIT\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\R00TKIT\\AppData\\Local\\Temp\\pip-install-x3hy6j34\\gdal\\setup.py'"'"'; __file__='"'"'C:\\Users\\R00TKIT\\AppData\\Local\\Temp\\pip-install-x3hy6j34\\gdal\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\R00TKIT\AppData\Local\Temp\pip-wheel-k4cul832'
#        cwd: C:\Users\R00TKIT\AppData\Local\Temp\pip-install-x3hy6j34\gdal\
#   Complete output (142 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.8
#   creating build\lib.win-amd64-3.8\osgeo
#   copying osgeo\gdal.py -> build\lib.win-amd64-3.8\osgeo
#   copying osgeo\gdalconst.py -> build\lib.win-amd64-3.8\osgeo
# ...
